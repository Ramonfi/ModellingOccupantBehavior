# %% [markdown]
# # **Übersichtsplot über eine Wohnung**
# ___

# %% [markdown]
# ## Importe

# %%
### Jupyter Einstellungen
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 

### Python Pakete
import matplotlib.pyplot as plt
from src.preprocessing import getDB
from src.templates import plotOverview
import src.style as style

### Datenbank Import
try:
    from src.preprocessing import BUID, ROOMS, APPS, DB, AMB, IND
except ImportError:
    getDB()
    from src.preprocessing import BUID, ROOMS, APPS, DB, AMB, IND
# Out:
# Lade WetterDB...
# Lade Raumklima...
# Lade gespeicherte Datenbank...
# Laden vollständig...

# %% [markdown]
# # **PLOT**

# %%
## Auswahl Wohneinheit
bui = 'MH'
app = 'S'

## Auswahl Zeitraum
start = '2021-11-10'
ende = '2021-11-12'

## Plot
plotOverview(bui, app, start, ende)
# Out:
# exportiere die zuletzt verwendete Figure...
