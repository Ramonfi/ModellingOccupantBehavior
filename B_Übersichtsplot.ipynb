# %% [markdown]
# # **Übersichtsplot über eine Wohnung**
# ___

# %% [markdown]
# ## **Importe**

# %% [markdown]
# ### Notebook Einstellungen

# %%
# %load_ext autoreload
# %autoreload 2

import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %% [markdown]
# ### Python Pakete

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ### Datenbanken

# %%
import RomansThesis as RT
from RomansThesis import DB, IND, AMB
# Out:
# Lade WetterDB...
# Lade Raumklima...
# Lade gespeicherte Datenbank...
# Laden vollständig...

# %% [markdown]
# ### Auswahl Wohneinheit

# %%
bui = 'MH'
app = 'S'

# %% [markdown]
# ### Auswahl Zeitraum

# %%
start = '2021-11-10'
ende = '2021-11-12'

# %% [markdown]
# # **PLOT**
#
# Der Plot stellt alle Messwerte für eine Wohnung für einen gewünschten Zeitraum dar.

# %%
RT.plotOverview(bui, app, start, ende)
